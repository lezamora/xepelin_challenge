# %% [markdown]
# ## Tuneo de hiperparámetros y entendimiento del modelo
#
# El objetivo de este notebook es buscar el mejor conjunto de hiperparámetros para el modelo seleccionado. Aprovechando que tenemos el mejor modelo posible, intentaremos entender que variables fueron las más importantes para la predicción.

# %% [markdown]
# ### Import de los paquetes

# %%
import joblib
import matplotlib.pyplot as plt
import numpy as np
import optuna
import pandas as pd
import seaborn as sns
import shap
from optuna.visualization import plot_optimization_history
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

from xepelin.evaluation import track_metrics

# %matplotlib inline
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %% [markdown]
# ### Configuraciones

# %%
# Variable para setear semilla
SEED = 0

# %%
np.random.seed(SEED)
optuna.logging.set_verbosity(optuna.logging.WARNING)

# %%
pd.set_option("display.max_columns", None)

# %% [markdown]
# ### Carga de datos

# %%
df = pd.read_csv("../data/processed/dataset_training_v0.csv")
df.shape
# Out:
# (2962, 18)

# %%
df.head()
# Out:
#    invoiceId  businessId  payerId  relationDays  relationRecurrence  \
# 0      11654           5     5015         428.0           10.166667
# 1      13430           5     5015         455.0            9.891304
# 2      15957           5     5015         493.0            9.264151
# 3      18135           5     5015         542.0            9.016667
# 4      19438           5     5015         562.0            8.920635
#
#    issuerCancelledInvoices  diasActividadPagador  facturaMorosa  \
# 0                 0.021942                2632.0              1
# 1                 0.020079                2659.0              0
# 2                 0.016629                2697.0              1
# 3                 0.014322                2746.0              0
# 4                 0.013314                2766.0              0
#
#    montoFacturaWsz  issuerInvoicesAmountWsz  Clients12MonthsWsz  \
# 0        4713103.0              187036960.0                 4.0
# ...

# %% [markdown]
# ### Split del conjunto de entrenamiento
#
# La estrategia utilizada para evaluar el modelo es separar los datos en train, test y validación:
# - El conjunto de **train** será el **80%** de los datos con los que contamos y será utilizado para entrenar el modelo.
# - El conjunto de **test**, será utilizado para evaluar la performance del modelo. Representará un **10%** de los datos y será seleccionado aleatoriamente.
# - Por último, el conjunto de **validación**, que será utilizado para el tuneo de los hiperparámetros, representará aproximadamente el **10%** de los datos. Dado que este conjunto no tiene que ser visto por el modelo desde ningún lugar, seleccionaremos las últimas facturas emitidas como emulando la utilización del modelo.

# %%
# Ordenamos los datos
df = df.sort_values("invoiceId").copy()
df.drop(columns=["invoiceId", "businessId", "payerId"], inplace=True)

# Especificar las características (X) y el objetivo (y)
x = df.drop(columns=["facturaMorosa"], axis=1)
y = df["facturaMorosa"]

# Obtener las últimas 150 filas para validación
x_val = x.iloc[-250:]
y_val = y.iloc[-250:]

# Eliminar las últimas 150 filas de x e y
x = x.iloc[:-250]
y = y.iloc[:-250]

# Dividir el conjunto en entrenamiento y prueba
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.1, random_state=SEED
)


# Verificamos las formas de los conjuntos resultantes
print("Formas de los conjuntos:")
print("Entrenamiento:", x_train.shape, y_train.shape)
print("Prueba:", x_test.shape, y_test.shape)
print("Validación:", x_val.shape, y_val.shape)


# Mostrar las formas de las particiones
print("Forma de x_train:", x_train.shape)
print("Forma de x_val:", x_val.shape)
print("Forma de x_test:", x_test.shape)
print("Forma de y_train:", y_train.shape)
print("Forma de y_val:", y_val.shape)
print("Forma de y_test:", y_test.shape)
# Out:
# Formas de los conjuntos:
# Entrenamiento: (2440, 14) (2440,)
# Prueba: (272, 14) (272,)
# Validación: (250, 14) (250,)
# Forma de x_train: (2440, 14)
# Forma de x_val: (250, 14)
# Forma de x_test: (272, 14)
# Forma de y_train: (2440,)
# Forma de y_val: (250,)
# Forma de y_test: (272,)

# %% [markdown]
# ### Tuning

# %% [markdown]
# #### Definimos la funcion objetivos y corremos diferentes trials

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 100, 300),
        "max_depth": trial.suggest_int("max_depth", 6, 100),
        "min_samples_split": trial.suggest_float("min_samples_split", 0.1, 1.0),
        "min_samples_leaf": trial.suggest_float("min_samples_leaf", 0.1, 0.5),
        "max_features": trial.suggest_float("max_features", 0.1, 1.0),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False]),
    }

    model = RandomForestClassifier(**params)
    model.fit(x_train, y_train)

    y_pred_prob = model.predict_proba(x_test)[:, 1]
    auc_score = roc_auc_score(y_test, y_pred_prob)

    return auc_score


study = optuna.create_study(
    direction="maximize"
)  # 'maximize' si estamos buscando maximizar el AUC-ROC
study.optimize(objective, n_trials=300, show_progress_bar=True)

# Obtener los mejores hiperparámetros encontrados
best_params = study.best_params
print("Mejores hiperparámetros:", best_params)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]
# Mejores hiperparámetros: {'n_estimators': 240, 'max_depth': 57, 'min_samples_split': 0.2988007341354103, 'min_samples_leaf': 0.11381781816451977, 'max_features': 0.6221448711302026, 'bootstrap': False}

# %% [markdown]
# #### Visualización de los trials

# %%
plot_optimization_history(study)

# %% [markdown]
# #### Entrenamiento
#
# Entrenamos el modelo con los mejores hiperparámetros seleccionados y validamos que no hayamos caido en overfitting.

# %%
# Entrenamos el modelo con los mejores hiperparámetros
best_model = RandomForestClassifier(**best_params)
best_model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=57,
#                        max_features=0.6221448711302026,
#                        min_samples_leaf=0.11381781816451977,
#                        min_samples_split=0.2988007341354103, n_estimators=240)

# %% [markdown]
# #### Resultados

# %% [markdown]
# ##### Evaluamos en el conjunto de test

# %%
_ = track_metrics(
    best_model,
    x_test,
    y_test,
    threshold=0.5,
)
# Out:
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#     Negativo       0.75      0.69      0.72       166
#     Positivo       0.57      0.63      0.60       106
#
#     accuracy                           0.67       272
#    macro avg       0.66      0.66      0.66       272
# weighted avg       0.68      0.67      0.67       272

# %% [markdown]
# ##### Evaluamos en el conjunto de validación

# %%
_ = track_metrics(
    best_model,
    x_val,
    y_val,
    threshold=0.5,
)
# Out:
# Informe de Clasificación:
#               precision    recall  f1-score   support
#
#     Negativo       0.82      0.75      0.78       177
#     Positivo       0.49      0.59      0.54        73
#
#     accuracy                           0.70       250
#    macro avg       0.66      0.67      0.66       250
# weighted avg       0.72      0.70      0.71       250

# %% [markdown]
# ### Guardado del modelo

# %%
# Guardar el modelo en un archivo con un nombre estandar
joblib.dump(best_model, "../models/model.joblib")
# Out:
# ['../models/model.joblib']

# %% [markdown]
# **Notas:**
#
# Luego de encontrar los mejores hiperparámetros conseguimos una pequeña mejora sobre le métrica optimizada. Validamos también que no hayamos ocasiano sobreajuste.

# %% [markdown]
# ### Entendimiento del modelo

# %% [markdown]
# #### Feature importance

# %%
# Obtengo la importancia de las características
feature_importances = best_model.feature_importances_

# Creo un DataFrame para facilitar el uso
feature_importance_df = pd.DataFrame(
    {"Feature": x.columns, "Importance": feature_importances}
)

# Ordeno por importancia
feature_importance_df = feature_importance_df.sort_values(
    by="Importance", ascending=False
)

# Creo un gráfico de barras con Seaborn
plt.figure(figsize=(8, 4))
sns.barplot(x="Importance", y="Feature", data=feature_importance_df, palette="Blues_r")
plt.title("Feature Importance - Random Forest")
plt.show()

# %% [markdown]
# **Notas:**
#
# La importancia de los features es una medida importante que permite tener una idea de la contribución de las variables al poder predictivo del modelo. La importancia se mide dada la capacidad que tiene la variable de discriminar correctamente entre las clases. Estas son las interpretaciones generales. Dado esta métrica, las 3 variables más importantes que nos ayudan a explicar los resultados son:
# - `payerAvgDiasMora`.
# - `payerRatioMorosidad`.
# - `diasActividadPagador`.

# %% [markdown]
# #### Shap values

# %%
# Calculamos SHAP values
explainer = shap.TreeExplainer(best_model)
shap_values = explainer.shap_values(x_test)

# %%
# Graficos los efectos de cada variable calculados por SHAP
shap.summary_plot(
    shap_values,
    x_test,
    plot_type="bar",
    class_names=["No Morosa", "Morosa"],
    plot_size=(10, 4),
    color_bar=False,
    cmap="plasma",
)

# %% [markdown]
# **NOTA:**
#
# A pesar de que es otro enfoque el que utiliza SHAP, obtenemos casi el mismo resultado que en feature importance, al menos en la elección de las 3 variables que más implicancia tiene.

# %% [markdown]
# #### Impacto de las 3 variables principales en la detección de mora

# %% [markdown]
# ##### Predicción de la clase positiva

# %%
shap.summary_plot(shap_values[1], x_test, max_display=3, plot_size=(10, 4))

# %% [markdown]
# **Notas:**
#
# Se observa algo que pudimos notar en el análisis exploratorio. Para las variables `payerAvgDiasMora` y `payerRatioMorosidad`, podemos notar que a valores más altos, la probabilidad de que la factura no se pague a término aumenta. Caso contrario con la variable `diasActividadPagador`, como mencionamos en los notebooks anteriores los pagadores con más antiguedad al parecer son los más confiables.
